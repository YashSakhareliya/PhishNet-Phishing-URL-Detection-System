# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./phishing_site_urls.csv')

# %%
df.head()
# Out:
#                                                  URL Label
# 0  nobell.it/70ffb52d079109dca5664cce6f317373782/...   bad
# 1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...   bad
# 2  serviciosbys.com/paypal.cgi.bin.get-into.herf....   bad
# 3  mail.printakid.com/www.online.americanexpress....   bad
# 4  thewhiskeydregs.com/wp-content/themes/widescre...   bad

# %%
df.shape # there are 549346 record
# Out:
# (549346, 2)

# %%
# chech any null value
df.isnull().sum()
# Out:
# URL      0
# Label    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549346 entries, 0 to 549345
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   URL     549346 non-null  object
#  1   Label   549346 non-null  object
# dtypes: object(2)
# memory usage: 8.4+ MB

# %%
df['Label'].unique()
# Out:
# array(['bad', 'good'], dtype=object)

# %%
# count how many good or bad value
df['Label'].value_counts()
# Out:
# Label
# good    392924
# bad     156422
# Name: count, dtype: int64

# %%
df['URL']
# Out:
# 0         nobell.it/70ffb52d079109dca5664cce6f317373782/...
# 1         www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...
# 2         serviciosbys.com/paypal.cgi.bin.get-into.herf....
# 3         mail.printakid.com/www.online.americanexpress....
# 4         thewhiskeydregs.com/wp-content/themes/widescre...
#                                 ...
# 549341                                      23.227.196.215/
# 549342                                   apple-checker.org/
# 549343                                    apple-iclods.org/
# 549344                                   apple-uptoday.org/
# 549345                                    apple-search.info
# Name: URL, Length: 549346, dtype: object

# %%
type(df['URL'][0])
# Out:
# str

# %%
df['URL'][0]
# Out:
# 'nobell.it/70ffb52d079109dca5664cce6f317373782/login.SkyPe.com/en/cgi-bin/verification/login/70ffb52d079109dca5664cce6f317373/index.php?cmd=_profile-ach&outdated_page_tmpl=p/gen/failed-to-load&nav=0.5.1&login_access=1322408526'

# %% [markdown]
# ## Create Dataset that contains all info about URLS

# %%
total_letter = len(df['URL'][0])
total_letter
# Out:
# 225

# %%
upper_letter = sum(1 for char in df['URL'][0] if char.isupper())
upper_letter
# Out:
# 2

# %%
lower_letter = sum(1 for char in df['URL'][0] if char.islower())
lower_letter
# Out:
# 133

# %%
total_number = sum(1 for char in df['URL'][0] if char.isdigit())
total_number
# Out:
# 58

# %%
total_dots = sum(1 for char in df['URL'][0] if char == '.')
total_dots
# Out:
# 6

# %%
total_desh = sum(1 for char in df['URL'][0] if char == '-')
total_desh
# Out:
# 4

# %%
total_slesh = sum(1 for char in df['URL'][0] if char == '/')
total_slesh
# Out:
# 10

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
symbol = string.punctuation

# %%
# total symbot
total_symbol = sum(1 for char in df['URL'][0] if char in symbol)
total_symbol
# Out:
# 32

# %%
unique_symbol = '!"#$%&\'()*+,:;<=>?@[\\]^_`{|}~'

# %%
total_unique_symbol = sum(1 for char in df['URL'][0] if char in unique_symbol)
total_unique_symbol
# Out:
# 12

# %%
# check total letters
total_number+upper_letter+lower_letter+total_symbol
# Out:
# 225

# %% [markdown]
# ### Now convert all into datafream

# %%
symbol = string.punctuation
unique_symbol = '!"#$%&\'()*+,:;<=>?@[\\]^_`{|}~'
def String_analysis(url,label):
    return {
        'URL':url,
        'Total-character':len(url),
        'Uppercase_letter':sum(1 for char in url if char.isupper()),
        'Lowercase_letter':sum(1 for char in url if char.islower()),
        'Total_numbers':sum(1 for char in url if char.isdigit()),
        'Total_symbol':sum(1 for char in url if char in symbol),
        'Total_slesh':sum(1 for char in url if char == '/'),
        'Total_dots':sum(1 for char in url if char == '.'),
        'Total_desh':sum(1 for char in url if char == '-'),
        'Label':label
    }

# %%
data = [String_analysis(row['URL'],row['Label']) for _,row in df.iterrows()]

# %%
data
# Out:
# [{'URL': 'nobell.it/70ffb52d079109dca5664cce6f317373782/login.SkyPe.com/en/cgi-bin/verification/login/70ffb52d079109dca5664cce6f317373/index.php?cmd=_profile-ach&outdated_page_tmpl=p/gen/failed-to-load&nav=0.5.1&login_access=1322408526',
#   'Total-character': 225,
#   'Uppercase_letter': 2,
#   'Lowercase_letter': 133,
#   'Total_numbers': 58,
#   'Total_symbol': 32,
#   'Total_slesh': 10,
#   'Total_dots': 6,
#   'Total_desh': 4,
#   'Label': 'bad'},
#  {'URL': 'www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrcmd=_home-customer&nav=1/loading.php',
#   'Total-character': 81,
#   'Uppercase_letter': 0,
#   'Lowercase_letter': 65,
#   'Total_numbers': 1,
#   'Total_symbol': 15,
#   'Total_slesh': 4,
#   'Total_dots': 5,
#   'Total_desh': 2,
#   'Label': 'bad'},
#  {'URL': 'serviciosbys.com/paypal.cgi.bin.get-into.herf.secure.dispatch35463256rzr321654641dsf654321874/href/href/href/secure/center/update/limit/seccure/4d7a1ff5c55825a2e632a679c2fd5353/',
#   'Total-character': 177,
# ...

# %%
data_fream = pd.DataFrame(data)

# %%
data_fream['Label'].value_counts()
# Out:
# Label
# good    392924
# bad     156422
# Name: count, dtype: int64

# %%
df['Label'].value_counts()
# Out:
# Label
# good    392924
# bad     156422
# Name: count, dtype: int64

# %%
data_fream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549346 entries, 0 to 549345
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   URL               549346 non-null  object
#  1   Total-character   549346 non-null  int64
#  2   Uppercase_letter  549346 non-null  int64
#  3   Lowercase_letter  549346 non-null  int64
#  4   Total_numbers     549346 non-null  int64
#  5   Total_symbol      549346 non-null  int64
#  6   Total_slesh       549346 non-null  int64
#  7   Total_dots        549346 non-null  int64
#  8   Total_desh        549346 non-null  int64
#  9   Label             549346 non-null  object
# dtypes: int64(8), object(2)
# memory usage: 41.9+ MB

# %%
data_fream.to_csv('Cleaned_phishing_url_data.csv')

# %%
df2 = pd.read_csv('Cleaned_phishing_url_data.csv')

# %%
df2
# Out:
#         Unnamed: 0                                                URL  \
# 0                0  nobell.it/70ffb52d079109dca5664cce6f317373782/...
# 1                1  www.dghjdgf.com/paypal.co.uk/cycgi-bin/webscrc...
# 2                2  serviciosbys.com/paypal.cgi.bin.get-into.herf....
# 3                3  mail.printakid.com/www.online.americanexpress....
# 4                4  thewhiskeydregs.com/wp-content/themes/widescre...
# ...            ...                                                ...
# 549341      549341                                    23.227.196.215/
# 549342      549342                                 apple-checker.org/
# 549343      549343                                  apple-iclods.org/
# 549344      549344                                 apple-uptoday.org/
# 549345      549345                                  apple-search.info
#
#         Total-character  Uppercase_letter  Lowercase_letter  Total_numbers  \
# ...
